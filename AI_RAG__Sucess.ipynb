# %% [markdown]
# <a href="https://colab.research.google.com/github/zayedrmdn/AI-RAG/blob/main/AI_RAG__Sucess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio_client
# Out:
# Collecting gradio_client
#   Downloading gradio_client-1.3.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio_client) (2024.6.1)
# Collecting httpx>=0.24.1 (from gradio_client)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio_client) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio_client) (24.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio_client) (4.12.2)
# Collecting websockets<13.0,>=10.0 (from gradio_client)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio_client) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio_client) (2024.8.30)
# Collecting httpcore==1.* (from httpx>=0.24.1->gradio_client)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio_client) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio_client) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.24.1->gradio_client)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio_client) (3.16.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio_client) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio_client) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio_client) (4.66.5)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.24.1->gradio_client) (1.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->gradio_client) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->gradio_client) (2.2.3)
# Downloading gradio_client-1.3.0-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.7/318.7 kB 2.9 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 2.4 MB/s eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.0 MB/s eta 0:00:00
# Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 6.4 MB/s eta 0:00:00
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: websockets, h11, httpcore, httpx, gradio_client
# Successfully installed gradio_client-1.3.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.2 websockets-12.0

# %%
pip install -U sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-3.1.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.4.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading sentence_transformers-3.1.1-py3-none-any.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-3.1.1

# %%
import os
from google.colab import auth
auth.authenticate_user()

os.environ['HuggingFace_TOKEN'] = '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'  # replace with your actual token

# %%
from gradio_client import Client
client = Client("yuntian-deng/ChatGPT")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loaded as API: https://yuntian-deng-chatgpt.hf.space ✔

# %%
question = "How do I configure GPIO pins for I2C communication on STM32, and what code is needed for setting up the clock speed to 100kHz? format the respose in markdown format"
question
# Out:
# 'How do I configure GPIO pins for I2C communication on STM32, and what code is needed for setting up the clock speed to 100kHz? format the respose in markdown format'

# %%
result = client.predict(
    inputs=question,   # Pass the question as input
    top_p=1,            # Default setting for top-p
    temperature=1,      # Default setting for temperature
    chat_counter=0,     # Initial chat counter
    chatbot=[],         # Empty chatbot history
    api_name="/predict" # API endpoint for predictions
)
print(result)
# Out:
# ([["You are a highly proficient firmware engineer. You have extensive expertise in firmware development, firmware coding, and maintaining firmware across various hardware platforms. Your task is to assist with firmware-related queries, particularly focusing on optimizing firmware development and resolving complex issues.\n\nCentralized Knowledge Base for Hardware Documentation:\nCentral Repository: Create a centralized repository where developers and manufacturers can upload detailed documentation of new hardware. This documentation will include specifications such as:\n- Microcontroller datasheets (e.g., STM32, ESP32, AVR)\n- Peripheral integration guides (e.g., I2C, SPI, UART sensors)\n- Communication protocols (e.g., Bluetooth, Zigbee, Wi-Fi)\n- Power consumption profiles and optimization techniques\n- Pin configuration diagrams and electrical characteristics\n- Firmware APIs for various development environments\nStructured Documentation: The repository will ensure that each document is indexed in a structured format that is easy to query. Information will be organized into sections like 'Pin Mappings,' 'Communication Protocols,' and 'Peripheral Integration' to streamline retrieval.\n\nUser: How do I configure GPIO pins for I2C communication on STM32?", 'Configuring GPIO pins for I2C communication on an STM32 microcontroller involves several steps. Below are the general steps you should follow to properly set up the GPIO pins for I2C. We\'ll assume you\'re using STM32CubeMX or direct register manipulation for configuration.\n\n### Steps to Configure GPIO for I2C\n\n1. **Select the I2C Peripheral:**\n   - Choose the I2C peripheral you want to use (e.g., I2C1, I2C2).\n   - In STM32CubeMX, enable the I2C interface in the "Pinout & Configuration" tab.\n\n2. **Assign GPIO Pins:**\n   - For I2C communication, you typically use two pins: SDA (Serial Data Line) and SCL (Serial Clock Line).\n   - STM32 microcontrollers usually have multiple pin configurations for I2C. Select the appropriate pins for SDA and SCL from the GPIO configuration options provided in STM32CubeMX.\n   - Examples of pins for I2C might include:\n     - I2C1: SCL -> PB6, SDA -> PB7\n     - I2C2: SCL -> PB10, SDA -> PB11\n   \n3. **Configure GPIO Settings:**\n   - Set the mode of the GPIO pins to **Alternate Function** (AF).\n   - Set the output type to **Open Drain** for both SDA and SCL. I2C communication requires open-drain configuration to allow multiple devices to pull the line low.\n   - Set the speed to **High Speed** (or as appropriate for your specific application).\n   - Enable the pull-up resistors on the SDA and SCL lines. You can select either pull-up or pull-down based on the bus configuration. Typically pull-ups are used.\n\n4. **Code Generation (if using STM32CubeMX):**\n   - After configuring the GPIO settings, generate the code using STM32CubeMX, which will set up the necessary initialization code in the `HAL_I2C_MspInit` function or similar initialization functions.\n   \n5. **Manual Pin Configuration (if not using STM32CubeMX):**\n   - If you prefer manual register configuration, you can do the following:\n   ```c\n   // Assuming STM32F4xx\n   RCC->AHB1ENR |= RCC_AHB1ENR_GPIOBEN; // Enable GPIOB clock\n\n   // Configure PB6 (SCL) and PB7 (SDA) for alternate function\n   GPIOB->MODER   &= ~(GPIO_MODER_MODE6 | GPIO_MODER_MODE7);\n   GPIOB->MODER   |= (GPIO_MODER_MODE6_1 | GPIO_MODER_MODE7_1); // Alternate function mode\n\n   // Set the alternate function for I2C\n   GPIOB->AFR[0] |= (4 << (6 * 4)) | (4 << (7 * 4)); // AF4 for I2C1\n\n   // Set the output type to Open Drain\n   GPIOB->OTYPER |= (GPIO_OTYPER_OT6 | GPIO_OTYPER_OT7);\n\n   // Set Speed\n   GPIOB->OSPEEDR |= (GPIO_OSPEEDR_OSPEED6 | GPIO_OSPEEDR_OSPEED7);\n   // Activate pull-up resistors\n   GPIOB->PUPDR  |= (GPIO_PUPDR_PU6 | GPIO_PUPDR_PU7);\n   ```\n\n6. **Initialize the I2C Peripheral:**\n   - In your main application code, initialize the I2C peripheral using the HAL library or di ...

# %%
import pandas as pd
import json

with open('/data.json') as f:
    data = json.load(f)

# Use pd.json_normalize to convert the JSON to a DataFrame
df = pd.json_normalize(data['AI-RAG-Datasheet'],
                     meta=['Microcontroller', 'PinMappings','CommunicationProtocols',['PowerProfiles', 'Voltage'], ['PowerProfiles', 'Current'], 'PeripheralIntegration'])

# Rename the columns for clarity
df.columns = ['Microcontroller', 'PinMappings', 'CommunicationProtocols', 'PowerProfiles_Voltage', 'CommunicationProtocols_Current', 'PeripheralIntegration']

# Display the DataFrame
df.head()
# Out:
#   Microcontroller               PinMappings  \
# 0         AVR-834  6 pin SPDT configuration
# 1        AVR-869C       6 pin configuration
# 2        PIC-1234                 8 pin DIP
# 3         STM-221               32 pin LQFP
# 4         MSP-430              20 pin TSSOP
#
#                    CommunicationProtocols  \
# 0  Standard SPDT control signals (28 VDC)
# 1                  Standard SPDT (28 VAC)
# 2                             I2C and SPI
# 3                               UART, I2C
# 4                                SPI, I2C
#
#                                PowerProfiles_Voltage  \
# 0  General purpose relay control in industrial an...
# 1     Used in aerospace or industrial switch control
# 2       Consumer electronics and sensor applications
# 3                    IoT devices and home automation
# 4                      Battery-operated applications
#
#   CommunicationProtocols_Current PeripheralIntegration
# 0                         28 VDC                3 Amps
# 1                         28 VDC     Varies with usage
# 2                          5 VDC                500 mA
# 3                        3.3 VDC                200 mA
# 4                          3 VDC                 15 mA

# %%
import json
import os
from sentence_transformers import SentenceTransformer
import numpy as np

# Initialize the SentenceTransformer model
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Function to get embedding for a text
def get_embedding(text):
    # Convert the input text into a list (if it's a single string)
    if isinstance(text, str):
        text = [text.replace('\n', ' ')]

    # Generate embeddings using SentenceTransformer
    embeddings = model.encode(text)

    # Return the first embedding as a Python list (convert from NumPy array)
    return embeddings[0].tolist()

sentence = "How do I configure GPIO pins for I2C communication on STM32, and what code is needed for setting up the clock speed to 100kHz? format the response in markdown format"
get_embedding(sentence)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [0.01563938334584236,
#  0.031236136332154274,
#  -0.14375051856040955,
#  0.049181584268808365,
#  -0.05428898334503174,
#  -0.01694389432668686,
#  -0.04018454626202583,
#  0.039567362517118454,
#  -0.09283953160047531,
#  -0.003166332608088851,
#  -0.017162015661597252,
#  -0.06290949136018753,
#  -0.08847495168447495,
#  -0.031986795365810394,
#  0.02855623885989189,
#  0.02671845629811287,
#  0.10847746580839157,
#  -0.021478353068232536,
#  0.04618505388498306,
#  0.02937079779803753,
#  0.10082385689020157,
#  -0.04909145087003708,
#  0.022333107888698578,
#  0.0355386883020401,
#  -0.050215426832437515,
#  0.024403369054198265,
#  0.04714575409889221,
#  0.032847318798303604,
#  -0.041982557624578476,
#  0.008539654314517975,
#  0.005674906075000763,
#  -0.08058268576860428,
#  0.11021793633699417,
#  0.02989285998046398,
#  0.003821807447820902,
#  0.000909399997908622,
#  0.12994100153446198,
#  -0.17159973084926605,
#  0.022686053067445755,
#  -0.012449391186237335,
#  0.014934361912310123,
#  0.02135043777525425,
#  0.012331766076385975,
#  0.04900598153471947,
#  0.001502779545262456,
#  0.013631097972393036,
#  0.0703212097287178,
#  0.03444407135248184,
#  -0.06204916536808014,
#  -0.003441083477810025,
#  0.01344993058592081,
#  0.0648769736289978,
#  -0.06346575915813446,
#  -0.02729262411594391,
#  0.010597317479550838,
#  0.049859482795000076,
#  -0.0646149143576622,
#  0.1058604046702385,
#  0.02706068754196167,
#  -0.030552901327610016,
#  0.09016622602939606,
#  -0.07002070546150208,
#  0.028844192624092102,
#  0.004002233035862446,
#  -0.01857573539018631,
#  0.0253343153744936,
#  0.027336828410625458,
#  0.04267396032810211,
#  0.043767668306827545,
#  -0.038223300129175186,
#  -0.027202937752008438,
#  0.003233809256926179,
#  0.010037023574113846,
#  0.02937341295182705,
#  -0.004578276537358761,
#  -0.017811253666877747,
#  -0.07393153011798859,
#  0.04958391189575195,
#  -0.02944387122988701,
#  -0.04371819645166397,
#  -0.0728832259774208,
#  -0.02280977927148342,
#  0.07368487864732742,
#  0.003470601746812463,
#  0.04587240889668465,
#  0.02880493737757206,
#  0.01221440639346838,
#  0.10433663427829742,
#  -0.031023940071463585,
#  0.019718611612915993,
#  -0.010108870454132557,
#  -0.0037882705219089985,
#  -0.06394772231578827,
#  -0.044225797057151794,
#  0.043396446853876114,
#  0.018573801964521408,
#  0.04282233864068985,
#  -0.026700709015130997,
#  -0.04048815742135048,
#  -0.039197858422994614,
#  -0.005001068580895662,
#  -0.06682580709457397,
#  -0.0625084638595581,
#  0.05913161858916283,
#  0.011166347190737724,
#  0.018859727308154106,
#  -0.006708122324198484,
#  -0.037931643426418304,
#  -0.036454107612371445,
#  -0.005404455587267876,
#  -0.029860589653253555,
#  -0.013577946461737156,
#  -0.06157909333705902,
#  0.03147875517606735,
#  0.030480165034532547,
#  0.05183646082878113,
#  -0.003004122292622924,
#  0.028926895931363106,
#  0.06264662742614746,
#  -0.07472512871026993,
#  -0.007794118020683527,
#  0.030264079570770264,
#  0.03486594930291176,
#  -0.023180440068244934,
#  0.029112795367836952,
#  -0.04626383259892464,
#  0.017176996916532516,
#  0.028622230514883995,
#  0.040089335292577744,
#  -0.05371285229921341,
#  0.019041648134589195,
#  -0.040706079453229904,
#  0.05774637684226036,
#  -0.05952027067542076,
#  0.013537724502384663,
#  -0.02907402068376541,
#  -0.002395640593022108,
#  0.02225661836564541,
#  0.05883200466632843,
#  -0.055478744208812714,
#  -0.08386273682117462]

# %%
import json
from sentence_transformers import SentenceTransformer

# Initialize the SentenceTransformer model for embedding
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Path to the JSON file (your file that contains multiple objects)
json_file_path = "/data.json"

# Open and read the JSON file
with open(json_file_path, 'r') as f:
    data = json.load(f)

# Dictionary to hold embeddings for each entry in the JSON file
embeddings = {}

# Iterate through the key-value pairs in the JSON data
for key, value in data.items():
    # Assuming each value is a dictionary or object to be embedded
    if isinstance(value, dict) or isinstance(value, list):
        # Flatten the object to a string representation for embedding
        flattened_text = json.dumps(value)
    else:
        # If value is a simple string or number, convert it to a string
        flattened_text = str(value)

    # Generate the embedding for the flattened text
    embedding = model.encode([flattened_text])[0].tolist()  # Convert NumPy array to list

    # Store the embedding in the dictionary with the original key
    embeddings[key] = {
        "embedding": embedding,
        "original_data": value
    }

# Write the embeddings to a new JSON file in a neat and tidy format
with open('embeddings_output.json', 'w+') as f:
    json.dump(embeddings, f, indent=4, separators=(',', ': '))

# %%
from gradio_client import Client
import json
from sentence_transformers import SentenceTransformer
from gradio_client import Client

# Load SentenceTransformer model for embedding
embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Load embeddings from a JSON file (which contains embeddings as dictionaries with metadata)
embeddings = json.load(open('/content/embeddings_output.json', 'r'))

# Initialize Gradio Client for Hugging Face model
client = Client("yuntian-deng/ChatGPT")

# Function to calculate cosine distance between two vectors
def cosine_distance(a, b):
    return 1 - sum([a_i * b_i for a_i, b_i in zip(a, b)]) / (
        sum([a_i ** 2 for a_i in a]) ** 0.5 * sum([b_i ** 2 for b_i in b]) ** 0.5
    )

# Function to generate embeddings for input text using SentenceTransformers
def get_embedding(text):
    return embedding_model.encode([text])[0]  # Single sentence embedding

# Find the nearest embedding to the given query embedding
def nearest_embedding(embedding):
    nearest, nearest_distance = None, 1

    for path, entry in embeddings.items():
        embedding2 = entry['embedding']  # Extract the actual embedding from the dictionary
        distance = cosine_distance(embedding, embedding2)
        if distance < nearest_distance:
            nearest, nearest_distance = path, distance

    return nearest
# Out:
# Loaded as API: https://yuntian-deng-chatgpt.hf.space ✔

# %%
from gradio_client import Client
import json
from sentence_transformers import SentenceTransformer
from gradio_client import Client

# Load SentenceTransformer model for embedding
embedding_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# Load embeddings from a JSON file (which contains embeddings as dictionaries with metadata)
embeddings = json.load(open('/content/embeddings_output.json', 'r'))

# Initialize Gradio Client for Hugging Face model
client = Client("yuntian-deng/ChatGPT")

# Function to calculate cosine distance between two vectors
def cosine_distance(a, b):
    return 1 - sum([a_i * b_i for a_i, b_i in zip(a, b)]) / (
        sum([a_i ** 2 for a_i in a]) ** 0.5 * sum([b_i ** 2 for b_i in b]) ** 0.5
    )

# Function to generate embeddings for input text using SentenceTransformers
def get_embedding(text):
    return embedding_model.encode([text])[0]  # Single sentence embedding

# Find the nearest embedding to the given query embedding
def nearest_embedding(embedding):
    nearest, nearest_distance = None, 1

    for path, entry in embeddings.items():
        embedding2 = entry['embedding']  # Extract the actual embedding from the dictionary
        distance = cosine_distance(embedding, embedding2)
        if distance < nearest_distance:
            nearest, nearest_distance = path, distance

    return nearest


while True:
    # Get user input
    prompt = input('user: ')

    if prompt.lower() == 'exit':
        break

    # Get the embedding of the user's input
    query_embedding = get_embedding(prompt)

    # Find the nearest embedding in the dataset
    context = nearest_embedding(query_embedding)

    # Read the context from the nearest match in the dataset
    data = embeddings[context]['embedding']  # Extract content from the nearest matched entryy

    user_message = prompt


    # Combine the system, facts, and user input
    system_message = (
        "You are a highly proficient firmware engineer. You have extensive expertise in firmware development, "
        "firmware coding, and maintaining firmware across various hardware platforms."
    )

    facts_message = (
        "A Centralized Knowledge Base is a repository for uploading detailed hardware documentation, including datasheets, integration guides, communication protocols, and firmware APIs. It is organized into structured, easy-to-query sections such as ""Pin Mappings"" and ""Communication Protocols"" to streamline retrieval."
    )

    # Combine everything into one input for the model
    combined_input = f"{system_message}\n\n{facts_message}\n\nUser: {user_message}"

    # Send the combined input to the model
    response = client.predict(
        inputs=combined_input,
        api_name="/predict"
    )

    # Output the assistant's response
    print(f"Assistant: {response}")
# Out:
# Loaded as API: https://yuntian-deng-chatgpt.hf.space ✔
# user: How do I configure GPIO pins for I2C communication on STM32, and what code is needed for setting up the clock speed to 100kHz?
# Assistant: ([['You are a highly proficient firmware engineer. You have extensive expertise in firmware development, firmware coding, and maintaining firmware across various hardware platforms.\n\nA Centralized Knowledge Base is a repository for uploading detailed hardware documentation, including datasheets, integration guides, communication protocols, and firmware APIs. It is organized into structured, easy-to-query sections such as Pin Mappings and Communication Protocols to streamline retrieval.\n\nUser: How do I configure GPIO pins for I2C communication on STM32, and what code is needed for setting up the clock speed to 100kHz?', 'To configure GPIO pins for I2C communication on an STM32 microcontroller, you typically need to follow these steps:\n\n### 1. Pin Configuration\nChoose the appropriate GPIO pins for your I2C interface. For instance, for I2C1, the default pins are:\n- **SCL (Serial Clock Line)**: Usually PB6 or PB8, depending on the STM32 variant you’re using.\n- **SDA (Serial Data Line)**: Usually PB7 or PB9.\n\n**Note**: Always check the datasheet or reference manual for your specific STM32 microcontroller to confirm the exact pinout and available alternatives.\n\n#### Setting Up GPIO in STM32 using HAL:\n\n1. **Enable GPIO Clock:**\n   Ensure the clock for the GPIO ports is enabled in your code.\n\n   ```c\n   __HAL_RCC_GPIOB_CLK_ENABLE(); // Example for GPIOB\n   ```\n\n2. **Configure the GPIO Pins for Alternate Function:**\n\n   Here, you will set the mode to `GPIO_MODE_AF_OD` (Open Drain) for I2C and set the pull-up resistors.\n\n   ```c\n   GPIO_InitTypeDef GPIO_InitStruct;\n   GPIO_InitStruct.Pin = GPIO_PIN_6 | GPIO_PIN_7; // Replace with your SCL and SDA pins\n   GPIO_InitStruct.Mode = GPIO_MODE_AF_OD; // Alternate Function Open Drain\n   GPIO_InitStruct.Pull = GPIO_PULLUP; // Pull-up resistors\n   GPIO_InitStruct.Speed = GPIO_SPEED_FREQ_HIGH; // Fast frequency\n   HAL_GPIO_Init(GPIOB, &GPIO_InitStruct); // Initialize GPIOB settings\n   ```\n\n### 2. I2C Peripheral Configuration\n\nYou need to configure the I2C peripheral itself to work properly, including setting the clock speed to 100kHz.\n\n#### Initializing I2C with HAL:\n\n1. **Enable I2C Clock:**\n   Enable the clock for the I2C peripheral (e.g., I2C1).\n\n   ```c\n   __HAL_RCC_I2C1_CLK_ENABLE(); // Example for I2C1\n   ```\n\n2. **Configure I2C:**\n\n   You will typically have a structure `I2C_HandleTypeDef` and configure it accordingly.\n\n   ```c\n   I2C_HandleTypeDef hi2c1;\n\n   hi2c1.Instance = I2C1;\n   hi2c1.Init.ClockSpeed = 100000;         // I2C speed 100kHz\n   hi2c1.Init.DutyCycle = I2C_DUTYCYCLE_2; // Standard Duty Cycle\n   hi2c1.Init.OwnAddress1 = 0;             // Own address (set to 0 for master)\n   hi2c1.Init.AddressingMode = I2C_ADDRESSINGMODE_7BIT;\n   hi2c1.Init.DualAddressMode = I2C_DUALADDRESS_DISABLE;\n   hi2c1.Init.OwnAddress2 = 0;\n   hi2c1.Init.GeneralCallMode = I2C_GENERALCALL_DISABLE;\n   hi2c1.Init.NoStretchMode = I2C_NOSTRETCH_DISABLE;\n\n   if (HAL_I2C_Init(&hi2c1) != HAL_OK) {\n       // Initialization Error\n       Error_Handler();\n   }\n   ```\n\n### 3. Additional Configuration\nEnsure that you handle clock configurations thoroughly. If your microcontroller has specific configurations for the I2C clock (like APB clock settings), ensure those are set accordingly.\n\n### Example Main Function\nBringing it all together, your main function would look something like this:\n\n```c\nint main(void) {\n    HAL_Init(); // Initialize the HAL Library\n    SystemClock_Config(); // Configure the system clock\n\n    // GPIO and I2C Initialization\n    __HAL_RCC_GPIOB_CLK_ENABLE(); // Enable GPIOB clock\n    __HAL_RCC_I2C1_CLK_ENABLE();   // Enable I2C1 Clock\n\n    GPIO_InitTypeDef GPIO_InitStruct;\n    GPIO_InitStruct.Pin = GPIO_PIN_6 | GPIO_PIN_7;\n    GPIO_InitStruct.Mode = GPIO_MODE_AF_OD; \n    GPIO_InitStruct.Pull = GPIO_PULLUP; \n    GPIO_InitStruct.Speed = GPIO_SPEED_FREQ_HIGH; \n    HAL_GPIO_Init(GPIOB, &GPIO_InitStru ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-4e2e823dd1c5> in <cell line: 38>()
#      38 while True:
#      39     # Get user input
# ---> 40     prompt = input('user: ')
#      41
#      42     if prompt.lower() == 'exit':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
